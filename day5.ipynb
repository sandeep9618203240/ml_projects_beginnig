# %%
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv("files/MSFT.csv")
df
# Out:
#       Unnamed: 0        Date        Open        High         Low       Close  \
# 0              0  1986-03-13    0.054693    0.062736    0.054693    0.060055
# 1              1  1986-03-14    0.060055    0.063272    0.060055    0.062199
# 2              2  1986-03-17    0.062199    0.063808    0.062199    0.063272
# 3              3  1986-03-18    0.063272    0.063808    0.061127    0.061663
# 4              4  1986-03-19    0.061663    0.062199    0.060055    0.060591
# ...          ...         ...         ...         ...         ...         ...
# 9656        9656  2024-07-09  467.000000  467.329987  458.000000  459.540009
# 9657        9657  2024-07-10  461.220001  466.459991  458.859985  466.250000
# 9658        9658  2024-07-11  462.980011  464.779999  451.549988  454.700012
# 9659        9659  2024-07-12  454.329987  456.359985  450.649994  453.549988
# 9660        9660  2024-07-15  453.420013  457.260010  451.429993  453.959991
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9656    17207200
# 9657    18196100
# 9658    23111200
# 9659    16311300
# 9660    13621481
#
# [9661 rows x 7 columns]

# %%
new=df.drop(columns=['Close','Date'])

# %%
new
# Out:
#       Unnamed: 0        Open        High         Low      Volume
# 0              0    0.054693    0.062736    0.054693  1031788800
# 1              1    0.060055    0.063272    0.060055   308160000
# 2              2    0.062199    0.063808    0.062199   133171200
# 3              3    0.063272    0.063808    0.061127    67766400
# 4              4    0.061663    0.062199    0.060055    47894400
# ...          ...         ...         ...         ...         ...
# 9656        9656  467.000000  467.329987  458.000000    17207200
# 9657        9657  461.220001  466.459991  458.859985    18196100
# 9658        9658  462.980011  464.779999  451.549988    23111200
# 9659        9659  454.329987  456.359985  450.649994    16311300
# 9660        9660  453.420013  457.260010  451.429993    13621481
#
# [9661 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x=new

# %%
y = df['Close']

# %%
x_tr,x_te,y_tr,y_te=train_test_split(x,y,test_size=0.2)

# %%
fog=linear_model.LinearRegression()

# %%
fog.fit(x_tr,y_tr)
# Out:
# LinearRegression()

# %%
gg=fog.predict(x_te)

# %%
for _
# Out:
# array([3.20187013e+02, 2.42584734e+01, 1.64363038e+01, ...,
#        1.36862502e+01, 1.00296956e-01, 2.21275970e+01])
