# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('files/diamonds.csv')
df

# %%
new=df.drop(columns=['price'])

# %%
new

# %%
pri=df.price

# %%
mode=LinearRegression()

# %%
# df1=pd.get_dummies(df['']])

# %%
df_dummies = pd.get_dummies(new[['cut', 'color', 'clarity']], drop_first=True)

# %%
df_dummies

# %%
new = pd.concat([new.drop(columns=['cut', 'color', 'clarity']), df_dummies], axis=1)

# %%
new

# %%
from sklearn.model_selection import train_test_split

# %%
new=new.drop(columns=['Unnamed: 0'])

# %%
new.columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Good', 'cut_Ideal',
#        'cut_Premium', 'cut_Very Good', 'color_E', 'color_F', 'color_G',
#        'color_H', 'color_I', 'color_J', 'clarity_IF', 'clarity_SI1',
#        'clarity_SI2', 'clarity_VS1', 'clarity_VS2', 'clarity_VVS1',
#        'clarity_VVS2'],
#       dtype='object')

# %%
mode.fit(new[['carat', 'depth', 'table', 'x', 'y', 'z', 'cut_Good', 'cut_Ideal',
       'cut_Premium', 'cut_Very Good', 'color_E', 'color_F', 'color_G',
       'color_H', 'color_I', 'color_J', 'clarity_IF', 'clarity_SI1',
       'clarity_SI2', 'clarity_VS1', 'clarity_VS2', 'clarity_VVS1',
       'clarity_VVS2']],pri)
# Out:
# LinearRegression()

# %%
input_data = {
    'carat': [0.7],
    'depth': [61.5],
    'table': [55.0],
    'x': [5.5],
    'y': [5.5],
    'z': [3.2],
    'cut_Good': [0],        # Cut is not Good
    'cut_Ideal': [1],       # Cut is not Ideal
    'cut_Premium': [0],     # Cut is Premium
    'cut_Very Good': [0],   # Cut is not Very Good
    'color_E': [0],         # Color is not E
    'color_F': [0],         # Color is F
    'color_G': [1],         # Color is not G
    'color_H': [0],         # Color is not H
    'color_I': [0],         # Color is not I
    'color_J': [0],         # Color is not J
    'clarity_IF': [0],      # Clarity is not IF
    'clarity_SI1': [0],     # Clarity is not SI1
    'clarity_SI2': [0],     # Clarity is not SI2
    'clarity_VS1': [1],     # Clarity is not VS1
    'clarity_VS2': [0],     # Clarity is VS2
    'clarity_VVS1': [0],    # Clarity is not VVS1
    'clarity_VVS2': [0]     # Clarity is not VVS2
}

# Create a DataFrame
input_df = pd.DataFrame(input_data)

# Predict the price
predicted_price = mode.predict(input_df)

print(f"Predicted price: {predicted_price[0]}")
# Out:
# Predicted price: 3960.5155786595724

# %%
train_df,test_df=train_test_split(df,test_size=0.20,random_state=42)

# %%
train_df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 26546       26547   2.01       Good     F     SI2   58.1   64.0  16231  8.23
# 9159         9160   1.01  Very Good     E     SI2   60.0   60.0   4540  6.57
# 14131       14132   1.10    Premium     H     VS2   62.5   58.0   5729  6.59
# 15757       15758   1.50       Good     E     SI2   61.5   65.0   6300  7.21
# 24632       24633   1.52  Very Good     G     VS1   62.1   57.0  12968  7.27
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 11284       11285   1.05  Very Good     I     VS2   62.4   59.0   4975  6.48
# 44732       44733   0.47      Ideal     D     VS1   61.0   55.0   1617  5.03
# 38158       38159   0.33  Very Good     F      IF   60.3   58.0   1014  4.49
# 860           861   0.90    Premium     J     SI1   62.8   59.0   2871  6.13
# 15795       15796   1.14    Premium     F     SI1   60.4   58.0   6320  6.82
#
#           y     z
# 26546  8.19  4.77
# ...

# %%
test_df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 1388         1389   0.24      Ideal     G    VVS1   62.1   56.0    559  3.97
# 50052       50053   0.58  Very Good     F    VVS2   60.0   57.0   2201  5.44
# 41645       41646   0.40      Ideal     E    VVS2   62.1   55.0   1238  4.76
# 42377       42378   0.43    Premium     E    VVS2   60.8   57.0   1304  4.92
# 17244       17245   1.55      Ideal     E     SI2   62.3   55.0   6901  7.44
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 44081       44082   0.50  Very Good     E     VS1   61.6   59.0   1554  5.06
# 23713       23714   0.25  Very Good     F    VVS2   61.6   57.0    633  4.05
# 31375       31376   0.31       Good     G    VVS1   58.0   62.0    761  4.42
# 21772       21773   1.23      Ideal     F     VS1   62.5   54.0   9836  6.85
# 4998         4999   1.08       Good     J     SI2   63.2   59.0   3742  6.40
#
#           y     z
# 1388   4.00  2.47
# ...
